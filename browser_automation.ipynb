# %%
import time
from selenium import webdriver
from time import sleep
driver=webdriver.Chrome("./chromedriver.exe")
from selenium.webdriver.common.keys import Keys
driver.get("http://facebook.com")
time.sleep(2)
driver.find_element_by_name("email").send_keys("jayprakashpandit.jppp@gmail.com")
time.sleep(2)
driver.find_element_by_name("pass").send_keys()
time.sleep(2)
driver.find_element_by_id("loginbutton").click()
driver.get("http://facebook.com")
while True:
    try:
        element=driver.find_element_by_xpath("//span[@class='_1vp5']")
        element.click()
        break
    except:
        pass
while True:
    try:
        driver.find_element_by_xpath("//a[@data-tab-key='friends']").click()
        break
    except:
        pass
from selenium.webdriver.common.keys import Keys
listProfileName=[]
movie=False
time.sleep(5)
while movie==False:
        try:
            movieEle=driver.find_element_by_xpath("//a[text()='Films']")
            break
        except Exception:
            profile=driver.find_elements_by_xpath("//div[@data-testid='friend_list_item']/a")
            for profilePic in profile:
                profileURL=profilePic.get_attribute("href")
                finalName=""
                if(profileURL.find("profile.php?id=")==-1):
                    finalName=profileURL[profileURL.index(".com/")+len(".com/"):profileURL.index("?")]
                else:
                    finalName=profileURL[profileURL.index("profile.php?id=")+len("profile.php?id="):profileURL.index("&")]
                print(finalName)
                listProfileName.append(finalName)
            profile[len(profile) - 1].send_keys(Keys.CONTROL +""+Keys.END)
msg="http://www.facebook.com/messages/t/Sonu.Kumar"
for item in listProfileName:
    driver.get("http://www.facebook.com/messages/t/{un}".format(un=item))
    driver.switch_to_active_element().send_keys("Hello!\n It's MACHINE LEARNING CLASS DEMO\nPlease don't Un_friend me.@\n")
    time.sleep(1)
driver.quit()
# Out:
# AnandKrDwivediBettiah
# prateek.edwin
# debopriya.ganguly
# princevishalbth
# shashibhushan.kumar.7545
# nikhil.pathak.1694059
# 100010224727605
# 100005921885440
# ujjwal.varsney
# thesauravraj
# 100004069685438
# vibhav.singh.714
# purooshottam.raj
# 100006743350316
# sanjaysingh0007
# 100012217663471
# arun.paji.1
# manish.dolby
# 100025205023061
# risav.raj.54
# AnandKrDwivediBettiah
# prateek.edwin
# debopriya.ganguly
# princevishalbth
# shashibhushan.kumar.7545
# nikhil.pathak.1694059
# 100010224727605
# 100005921885440
# ujjwal.varsney
# thesauravraj
# 100004069685438
# vibhav.singh.714
# purooshottam.raj
# 100006743350316
# sanjaysingh0007
# 100012217663471
# arun.paji.1
# manish.dolby
# 100025205023061
# risav.raj.54
# AnandKrDwivediBettiah
# prateek.edwin
# debopriya.ganguly
# princevishalbth
# shashibhushan.kumar.7545
# nikhil.pathak.1694059
# 100010224727605
# 100005921885440
# ujjwal.varsney
# thesauravraj
# 100004069685438
# vibhav.singh.714
# purooshottam.raj
# ...

# %%
driver=webdriver.Chrome("./chromedriver.exe")

# %%
import time
from selenium.webdriver.common.keys import Keys
driver.get("http://facebook.com")
time.sleep(2)
driver.find_element_by_name("email").send_keys("jayprakashpandit.jppp@gmail.com")
time.sleep(2)
driver.find_element_by_name("pass").send_keys("")
time.sleep(2)
driver.find_element_by_id("loginbutton").click()
driver.get("http://facebook.com")
while True:
    try:
        element=driver.find_element_by_xpath("//span[@class='_1vp5']")
        element.click()
        break
    except:
        pass
while True:
    try:
        driver.find_element_by_xpath("//a[@data-tab-key='friends']").click()
        break
    except:
        pass
    from selenium.webdriver.common.keys import Keys
    listProfileName=[]
    movie=False
    time.sleep(5)
    while movie==False:
        try:
            movieEle=driver.find_element_by_xpath("//a[text()='Films']")
            break
            except Exception:
                profile=driver.find_elements_by_xpath("//div[@data-testid='friend_list_item']/a")
            for profilePic in profile:
                profileURL=profilePic.get_attribute("href")
                finalName=""
                if(profileURL.find("profile.php?id=")==-1):
                    finalName=profileURL[profileURL.index(".com/")+len(".com/"):
                                         profileURL.index("?")]
                    else:
                        finalName=profileURL[profileURL.index("profile.php?id=")+len("profile.php?id="):
                                             profileURL.index("&")]
                        print(finalName)
                        listProfileName.append(finalName)
                        profile[len(profile)-1].send_keys(Keys.CONTROL+""Keys.END)

                        msg="http://www.facebook.com/messages/t/sonu.kumar"
                        for item in listProfileName:
                            driver.get("http://www.facebook.com/messages/t/{un}".format(un=item))
                            
                            driver.switch_to_active_element().send_keys("Hello!\n It's MACHINE LEARNING CLASS DEMO\n
                            Please don't Un_friend me.@\n")
                            time.sleep(1)
                            driver.quit()
# Out:
#   File "<ipython-input-12-5583d3e40df9>", line 32
#     except Exception:
#          ^
# SyntaxError: invalid syntax

# %%
 from selenium.webdriver.common.keys import Keys
    listProfileName=[]
    movie=False
    time.sleep(5)
    while movie==False:
        try:
            movieEle=driver.find_element_by_xpath("//a[text()='Films']")
            break
            except Exception:
                profile=driver.find_elements_by_xpath("//div[@data-testid='friend_list_item']/a")
            for profilePic in profile:
                profileURL=profilePic.get_attribute("href")
                finalName=""
                if(profileURL.find("profile.php?id=")==-1):
                    finalName=profileURL[profileURL.index(".com/")+len(".com/"):
                                         profileURL.index("?")]
                    else:
                        finalName=profileURL[profileURL.index("profile.php?id=")+len("profile.php?id="):
                                             profileURL.index("&")]
                        print(finalName)
                        listProfileName.append(finalName)
                        profile[len(profile)-1].send_keys(Keys.CONTROL+""Keys.END)

                        #msg="http://www.facebook.com/messages/t/sonu.kumar"
                        for item in listProfileName:
                            driver.get("http://www.facebook.com/messages/t/{un}".format(un=item))
                            
                            driver.switch_to_active_element().send_keys("Hello!\n It's MACHINE LEARNING CLASS DEMO\n
                            Please don't Un_friend me.@\n")
                            time.sleep(1)
                            driver.quit()
# Out:
#   File "<ipython-input-14-9594a6ffc44f>", line 2
#     listProfileName=[]
#     ^
# IndentationError: unexpected indent

# %%
from selenium import webdriver

# %%
d = webdriver.Chrome("./chromedriver.exe")

# %%
d.get("https://www.techsimplus.com")
