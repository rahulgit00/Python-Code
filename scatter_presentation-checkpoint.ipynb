# %%
import pandas as pd

# %%
df=pd.read_csv("./nyc_weather.csv")

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    01/01/16           38        23        52                 30.03
# 1    01/02/16           36        18        46                 30.02
# 2    01/03/16           40        21        47                 29.86
# 3    01/04/16           25         9        44                 30.05
# 4    01/05/16           20        -3        41                 30.57
# 5    01/06/16           33         4        35                 30.50
# 6    01/07/16           39        11        33                 30.28
# 7    01/08/16           39        29        64                 30.20
# 8    01/09/16           44        38        77                 30.16
# 9    01/10/16           50        46        71                 29.59
# 10   01/11/16           33         8        37                 29.92
# 11   01/12/16           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df[["Temperature","Humidity"]]
# Out:
#     Temperature  Humidity
# 0            38        52
# 1            36        46
# 2            40        47
# 3            25        44
# 4            20        41
# 5            33        35
# 6            39        33
# 7            39        64
# 8            44        77
# 9            50        71
# 10           33        37
# 11           35        53
# 12           26        42
# 13           30        47
# 14           43        62
# 15           47        70
# 16           36        66
# 17           25        53
# 18           22        42
# 19           32        49
# 20           31        45
# 21           26        41
# 22           26        78
# 23           28        53
# 24           34        54
# 25           43        56
# 26           41        45
# 27           37        51
# 28           36        50
# 29           34        46
# 30           46        52

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot("Humidity")
plt.plot("Temperature")

# %%
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01/01/16           38        23        52                 30.03
# 1  01/02/16           36        18        46                 30.02
# 2  01/03/16           40        21        47                 29.86
# 3  01/04/16           25         9        44                 30.05
# 4  01/05/16           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df[["Temperature","Humidity"]]
# Out:
#     Temperature  Humidity
# 0            38        52
# 1            36        46
# 2            40        47
# 3            25        44
# 4            20        41
# 5            33        35
# 6            39        33
# 7            39        64
# 8            44        77
# 9            50        71
# 10           33        37
# 11           35        53
# 12           26        42
# 13           30        47
# 14           43        62
# 15           47        70
# 16           36        66
# 17           25        53
# 18           22        42
# 19           32        49
# 20           31        45
# 21           26        41
# 22           26        78
# 23           28        53
# 24           34        54
# 25           43        56
# 26           41        45
# 27           37        51
# 28           36        50
# 29           34        46
# 30           46        52

# %%
df.head(7)
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01/01/16           38        23        52                 30.03
# 1  01/02/16           36        18        46                 30.02
# 2  01/03/16           40        21        47                 29.86
# 3  01/04/16           25         9        44                 30.05
# 4  01/05/16           20        -3        41                 30.57
# 5  01/06/16           33         4        35                 30.50
# 6  01/07/16           39        11        33                 30.28
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
# ...

# %%
dg=df.sort_values(["Temperature","Humidity"],ascending=["True","True"])

# %%
dg.dropna(how="all")
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 4    01/05/16           20        -3        41                 30.57
# 18  1/19/2016           22         3        42                 30.03
# 3    01/04/16           25         9        44                 30.05
# 17  1/18/2016           25         6        53                 29.83
# 21  1/22/2016           26         6        41                 30.21
# 12  1/13/2016           26         4        42                 29.94
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 13  1/14/2016           30        12        47                 29.95
# 20  1/21/2016           31        11        45                 30.15
# 19  1/20/2016           32        15        49                 30.13
# 5    01/06/16           33         4        35                 30.50
# 10   01/11/16           33         8        37                 29.92
# ...

# %%
dd=dg[["Temperature","Humidity"]]

# %%
dd
# Out:
#     Temperature  Humidity
# 4            20        41
# 18           22        42
# 3            25        44
# 17           25        53
# 21           26        41
# 12           26        42
# 22           26        78
# 23           28        53
# 13           30        47
# 20           31        45
# 19           32        49
# 5            33        35
# 10           33        37
# 29           34        46
# 24           34        54
# 11           35        53
# 1            36        46
# 28           36        50
# 16           36        66
# 27           37        51
# 0            38        52
# 6            39        33
# 7            39        64
# 2            40        47
# 26           41        45
# 25           43        56
# 14           43        62
# 8            44        77
# 30           46        52
# 15           47        70
# 9            50        71

# %%
y=dd["Temperature"]

# %%
x=dd["Humidity"]

# %%
plt.scatter(x,y)
plt.xlabel("values of Humidity")
plt.ylabel("values of Temperature")
plt.title("Temperature vs Humidity curve")
plt.grid()
plt.show()
