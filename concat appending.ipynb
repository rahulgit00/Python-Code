# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import mpl_toolkits
# %matplotlib inline

# %%
df1=pd.read_csv("./machinelearning.csv")
df2=pd.read_csv("./ai.csv")
df3=pd.read_csv("./data_analyst.csv")
df4=pd.read_csv("./datascience2.csv")

# %%
df=pd.concat([df1,df2,df3,df4],axis=0).drop_duplicates()

# %%
df.shape
# Out:
# (1384, 6)

# %%
df["Sponsored"].value_counts()
# Out:
# Organic      1207
# Sponsored     177
# Name: Sponsored, dtype: int64

# %%
g=df.groupby("Company")
g.count()
# Out:
#                                             Title  Location  Salary  \
# Company
# 123Stores                                       1         1       1
# 159 Solutions                                   1         1       1
# 159 Solutions, Inc.                             1         1       1
# 24/7 Customers Pvt. Ltd                         1         1       1
# 360 Digital Transformation.com                  1         1       1
# 3D India                                        1         1       1
# 3D PLM Software Solutions Ltd                   1         1       1
# 3SC Solutions                                   1         1       1
# 72-Pixels                                       1         1       1
# 8Minutes                                        1         1       1
# 99Plus IT Solutions                             1         1       1
# A Client of Superior Talent India               1         1       1
# A Society Consulting                            1         1       1
# A and P Enterprises                             1         1       1
# AASC Strategi Consulting                        1         1       1
# ADCI - Karnataka                                2         2       2
# AI Enterprise                                   1         1       1
# AIEnterprise                                    1         1       1
# AIG                                             3         3       3
# AIONIOS LAB                                     1         1       1
# AISPL - Karnataka                               2         2       2
# AMIGAIT TECHNOLOGIES (OPC) PRIVATE LIMITED      1         1       1
# ARDEM Data Services Private Limited             1         1       1
# ARYUSH INFOTECH INDIA PRIVATE LIMITED           1         1       1
# ASSPL - Karnataka                               1         1       1
# AT&T                                            1         1       1
# ATOS LEO                                        1         1       1
# AaNeel                                          1         1       1
# Aarvi                                           1         1       1
# Absolutdata                                     2         2       2
# ...                                           ...       ...     ...
# cross-tab marketing services pvt.               1         1       1
# cube26                                          1         1       1
# e10                                             1         1       1
# eNFLUENCE IT Services Pvt Ltd                   1         1       1
# eShopbox                                        1         1       1
# edgetensor                                      1         1       1
# euler systems                                   1         1       1
# graffiti software solutions Pvt .Ltd            1         1       1
# greyatom school of data science                 1         1       1
# hCapital                                        1         1       1
# i-runway                                        1         1       1
# iManage.com                                     1         1       1
# iSOCRATES                                       1         1       1
# interface.ai                                    1         1       1
# iqm.com                                         1         1       1
# itvedant                                        1         1       1
# lemark institute of art                         1         1       1
# litmass analytics                               1         1       1
# mBreath Technologies Private Limited            1         1       1
# nfaktor                                         1         1       1
# oyorooms.com                                    2         2       2
# rochepharmaceutical                             1         1       1
# sRide                                           1         1       1
# simplifai cognitive services                    1         1       1
# smartecosemantics                               1         1       1
# staffiohr                                       2         2       2
# sysinfotools software                           1         1       1
# tracarta                                        1         1       1
# upGrad                                          1         1       1
# white hedge                                     1         1       1
#
#                                             Sponsored  Description
# Company
# 123Stores                                           1            1
# 159 Solutions                                       1            1
# 159 Solutions, Inc.                                 1            1
# 24/7 Customers Pvt. Ltd                             1            1
# 360 Digital Transformation.com                      1            1
# 3D India                                            1            1
# 3D PLM Software Solutions Ltd                       1            1
# 3SC Solutions                                       1            1
# 72-Pixels                                           1            1
# 8Minutes                                            1            1
# 99Plus IT Solutions                                 1            1
# A Client of Superior Talent India                   1            1
# A Society Consulting                                1            1
# A and P Enterprises                                 1            1
# AASC Strategi Consulting                            1            1
# ADCI - Karnataka                                    2            2
# AI Enterprise                                       1            1
# AIEnterprise                                        1            1
# AIG                                                 3            3
# AIONIOS LAB                                         1            1
# AISPL - Karnataka                                   2            2
# AMIGAIT TECHNOLOGIES (OPC) PRIVATE LIMITED          1            1
# ARDEM Data Services Private Limited                 1            1
# ARYUSH INFOTECH INDIA PRIVATE LIMITED               1            1
# ASSPL - Karnataka                                   1            1
# AT&T                                                1            1
# ATOS LEO                                            1            1
# AaNeel                                              1            1
# Aarvi                                               1            1
# Absolutdata                                         2            2
# ...                                               ...          ...
# cross-tab marketing services pvt.                   1            1
# cube26                                              1            1
# e10                                                 1            1
# eNFLUENCE IT Services Pvt Ltd                       1            1
# eShopbox                                            1            1
# edgetensor                                          1            1
# euler systems                                       1            1
# graffiti software solutions Pvt .Ltd                1            1
# greyatom school of data science                     1            1
# hCapital                                            1            1
# i-runway                                            1            1
# iManage.com                                         1            1
# iSOCRATES                                           1            1
# interface.ai                                        1            1
# iqm.com                                             1            1
# itvedant                                            1            1
# lemark institute of art                             1            1
# litmass analytics                                   1            1
# mBreath Technologies Private Limited                1            1
# nfaktor                                             1            1
# oyorooms.com                                        2            2
# rochepharmaceutical                                 1            1
# sRide                                               1            1
# simplifai cognitive services                        1            1
# smartecosemantics                                   1            1
# staffiohr                                           2            2
# sysinfotools software                               1            1
# tracarta                                            1            1
# upGrad                                              1            1
# white hedge                                         1            1
#
# [930 rows x 5 columns]

# %%
value=g.count()["Title"].sort_values(ascending=False)[:20]
value.plot("bar",figsize=(20,5))
plt.show()

# %%
value.plot("pie",figsize=(20,5))
plt.show()

# %%
import nltk

# %%
from nltk import word_tokenize
from nltk.corpus import stopwords
stop_words=stopwords.words("")

# %%
def CleanData(desc):
    desc=word_tokenize(desc)
    for word in desc:
        lower=word.lower()
        if lower not in stop_words:
            data.append(lower)
    return data

# %%
tags_df=df["Description"].apply(CleanData)

# %%
from collections import Counter
result=tags_df.apply(Counter).sum().items()
result=sorted(result,key=lambda kv:kv[1],)

# %%
result_series

# %%
skills=["pandas"]
